# %%
import os
import pandas as pd
import requests
import json
import numpy as np
import folium
#To create colormaps
import branca
from branca.colormap import  LinearColormap

#url found using Postman
url='http://bl.ocks.org/herrstucki/raw/4327678/aa6f466b7600651bd57838ca70b72ce07e79165d/ch.json'
swiss_dict= requests.get(url).json()


with open('neighbors.json') as f:
    neighbors_index=json.load(f)
#neighbors_index of type list

communes=pd.DataFrame()

municipalities = swiss_dict['objects']['municipalities']['geometries'][:]
print(type(municipalities))
municipalities = pd.DataFrame(municipalities)
#communes['index']= municipalities['id']
communes['name']=pd.DataFrame(list(municipalities['properties'].values))
#communes.set_index('index')
communes
# Out:
# <class 'list'>
#                        name
# 0           Aeugst am Albis
# 1        Affoltern am Albis
# 2                Bonstetten
# 3           Hausen am Albis
# 4                  Hedingen
# 5           Kappel am Albis
# 6                    Knonau
# 7               Maschwanden
# 8            Mettmenstetten
# 9                  Obfelden
# 10                Ottenbach
# 11               Rifferswil
# 12                Stallikon
# 13        Wettswil am Albis
# 14                  Adlikon
# 15              Benken (ZH)
# 16           Berg am Irchel
# 17           Buch am Irchel
# 18                  Dachsen
# 19                     Dorf
# 20              Feuerthalen
# 21                   Flaach
# 22               Flurlingen
# 23              Andelfingen
# 24                 Henggart
# 25                 Humlikon
# 26         Kleinandelfingen
# 27          Laufen-Uhwiesen
# 28                Marthalen
# 29            Oberstammheim
# ...                     ...
# 2395                 Cornol
# 2396             Courchavon
# 2397              Courgenay
# 2398             Courtedoux
# 2399              Damphreux
# 2400                   Fahy
# 2401              Fontenais
# 2402          Grandfontaine
# 2403                 Lugnez
# 2404             Porrentruy
# 2405                Rocourt
# 2406           Vendlincourt
# 2407          Basse-Allaine
# 2408          Clos du Doubs
# 2409            Haute-Ajoie
# 2410             La Baroche
# 2411              Thunersee
# 2412            Brienzersee
# 2413         Bielersee (BE)
# 2414         Bielersee (NE)
# 2415  Lac de Neuchâtel (FR)
# 2416  Lac de Neuchâtel (VD)
# 2417  Lac de Neuchâtel (NE)
# 2418      Lac de Morat (VD)
# 2419          Bodensee (SG)
# 2420          Bodensee (TG)
# 2421         Lago di Lugano
# 2422          Lago Maggiore
# 2423         Lac Léman (VD)
# 2424         Lac Léman (VS)
#
# [2425 rows x 1 columns]

# %%
neighbors_index
s= pd.Series(neighbors_index)
neighbors= pd.DataFrame()
neighbors['indexes']=s
neighbors['municipality']=communes['name']
neighbors['neighbors']=neighbors['indexes'].map(lambda x: pd.Series(x).map(neighbors['municipality']).values)
neighbors
# Out:
#                                                 indexes  \
# 0                                 [1, 3, 8, 11, 12, 98]
# 1                            [0, 4, 8, 9, 10, 12, 1421]
# 2                                [4, 12, 13, 159, 1434]
# 3                      [0, 5, 11, 94, 95, 98, 704, 708]
# 4                          [1, 2, 12, 1412, 1421, 1434]
# 5                               [3, 6, 8, 11, 704, 711]
# 6                                   [5, 7, 8, 705, 711]
# 7                                   [6, 8, 9, 705, 706]
# 8                                [0, 1, 5, 6, 7, 9, 11]
# 9                              [1, 7, 8, 10, 706, 1528]
# 10                             [1, 9, 1421, 1517, 1528]
# 11                                         [0, 3, 5, 8]
# 12              [0, 1, 2, 4, 13, 93, 98, 160, 166, 170]
# 13                                         [2, 12, 160]
# 14                                [23, 25, 30, 32, 141]
# 15                                 [18, 27, 28, 31, 33]
# 16                               [17, 21, 36, 44, 1100]
# 17                           [16, 19, 36, 44, 142, 150]
# 18                                         [15, 27, 31]
# 19                            [17, 23, 24, 25, 36, 150]
# 20                                 [22, 27, 1101, 1611]
# 21                     [16, 23, 26, 28, 36, 1097, 1100]
# 22                                 [20, 27, 1099, 1101]
# 23                         [14, 19, 21, 25, 26, 30, 36]
# 24                              [19, 25, 141, 148, 150]
# 25                                [14, 19, 23, 24, 141]
# 26                                 [21, 23, 28, 30, 33]
# 27                     [15, 18, 20, 22, 33, 1099, 1611]
# 28                     [15, 21, 26, 31, 33, 1097, 1100]
# 29                           [35, 37, 1618, 1654, 1661]
# ...                                                 ...
# 2395                           [2389, 2397, 2408, 2410]
# 2396                           [2393, 2394, 2404, 2407]
# 2397                     [2389, 2395, 2401, 2404, 2408]
# 2398                           [2393, 2401, 2404, 2409]
# 2399               [2390, 2392, 2394, 2403, 2406, 2407]
# 2400                           [2393, 2402, 2405, 2409]
# 2401                     [2397, 2398, 2404, 2408, 2409]
# 2402                                 [2400, 2405, 2409]
# 2403                                 [2390, 2399, 2407]
# 2404         [2389, 2393, 2394, 2396, 2397, 2398, 2401]
# 2405                                 [2400, 2402, 2409]
# 2406                     [2389, 2392, 2394, 2399, 2410]
# 2407               [2391, 2393, 2394, 2396, 2399, 2403]
# 2408  [2354, 2374, 2383, 2387, 2388, 2395, 2397, 240...
# 2409               [2393, 2398, 2400, 2401, 2402, 2405]
# 2410         [2354, 2355, 2368, 2389, 2395, 2406, 2408]
# 2411  [315, 317, 321, 330, 338, 441, 499, 503, 507, ...
# 2412                     [318, 319, 328, 333, 334, 335]
# 2413  [216, 274, 276, 279, 284, 407, 415, 418, 419, ...
# 2414                                  [276, 2299, 2413]
# 2415  [716, 719, 723, 725, 743, 744, 1852, 2066, 213...
# 2416  [744, 1850, 1852, 1907, 1910, 1911, 1916, 1920...
# 2417  [277, 1850, 2272, 2273, 2276, 2278, 2282, 2283...
# 2418                       [834, 849, 1849, 1851, 1852]
# 2419         [1145, 1147, 1148, 1149, 1158, 1594, 2420]
# 2420  [1108, 1590, 1592, 1595, 1597, 1598, 1600, 162...
